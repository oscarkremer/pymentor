# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.stats.api as sms
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
sns.set()

# %%
points = pd.read_csv('../data/results/points.csv')
results = pd.read_csv('../data/results/results.csv')

# %%
points.head(10)
# Out:
#            x             y          z    theta1    theta2    theta3    theta4  \
# 0  10.000000 -3.061617e-16  10.000000  0.000000  0.613167  3.829706  4.981905
# 1   9.999466  1.764580e-05  10.000040  0.000002  0.613156  3.829688  4.981893
# 2   9.997865  7.052864e-05  10.000160  0.000007  0.613122  3.829634  4.981856
# 3   9.995201  1.585499e-04  10.000359  0.000016  0.613065  3.829544  4.981795
# 4   9.991478  2.815885e-04  10.000637  0.000028  0.612985  3.829419  4.981709
# 5   9.986698  4.395015e-04  10.000992  0.000044  0.612883  3.829258  4.981600
# 6   9.980866  6.321239e-04  10.001422  0.000063  0.612758  3.829062  4.981466
# 7   9.973983  8.592689e-04  10.001927  0.000086  0.612611  3.828830  4.981308
# 8   9.966055  1.120728e-03  10.002505  0.000112  0.612441  3.828563  4.981126
# 9   9.957083  1.416273e-03  10.003152  0.000142  0.612249  3.828261  4.980920
#
#      theta5
# 0  3.141593
# 1  3.141590
# 2  3.141583
# 3  3.141570
# 4  3.141552
# 5  3.141530
# 6  3.141502
# ...

# %%
results.head(10)
# Out:
#      distance
# 0  189.696566
# 1  135.022678
# 2  135.022678
# 3  135.022678
# 4  135.022678
# 5  135.022678
# 6  135.022678
# 7  135.022678
# 8  103.633889
# 9  103.633889

# %%
t = np.linspace(0,10,len(points['theta1'].values))
plt.plot(t, 180*points['theta1']/np.pi, label = 'Polinomy')
plt.xlabel('time')
plt.ylabel('Angle 1 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(t, 180*points['theta2']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 2 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta3']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 3 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e50e8411e372> in <module>
#       1 t = np.linspace(0,10,150)
# ----> 2 plt.plot(t, 180*points['theta3']/np.pi, label = 'Genetic Algorithm')
#       3 plt.xlabel('time')
#       4 plt.ylabel('Angle 3 - rad', labelpad=0)
#       5 plt.legend(loc='upper right')
#
# ~/miniconda3/envs/mentor/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/miniconda3/envs/mentor/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
plt.plot(t, 180*points['theta4']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 4 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a14ff135f354> in <module>
#       1 t = np.linspace(0,10,150)
# ----> 2 plt.plot(t, 180*points['theta4']/np.pi, label = 'Genetic Algorithm')
#       3 plt.xlabel('time')
#       4 plt.ylabel('Angle 4 - rad', labelpad=0)
#       5 plt.legend(loc='upper right')
#
# ~/miniconda3/envs/mentor/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/miniconda3/envs/mentor/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta5']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 5 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['x'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('X (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['y'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Y (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['z'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Z (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()
